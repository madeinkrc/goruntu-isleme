# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.xlabel('deneme')
plt.show()

# %%
ls
# Out:
#  C s�r�c�s�ndeki birimin etiketi yok.
#  Birim Seri Numaras�: AE56-4189
#
#  C:\Users\Karaca\G”r�nt� ˜Ÿleme Dersi dizini
#
# 04.11.2017  13:45    <DIR>          .
# 04.11.2017  13:45    <DIR>          ..
# 04.11.2017  13:45    <DIR>          .ipynb_checkpoints
# 02.11.2017  23:59             2.173 hafta1-1.ipynb
# 04.11.2017  13:09           414.732 hafta1-2.ipynb
# 04.11.2017  13:14           370.022 hafta2-1.ipynb
# 04.11.2017  13:26             3.641 hafta3-1.ipynb
# 04.11.2017  13:32           204.765 hafta3-2.ipynb
# 04.11.2017  13:43           204.950 hafta3-3.ipynb
# 04.11.2017  13:45           315.381 hafta4-1.ipynb
# 02.11.2017  23:10           255.957 hafta4-2.ipynb
# 02.11.2017  23:16            83.537 hafta4-3.ipynb
# 02.11.2017  23:25           274.303 hafta4-4.ipynb
# 02.11.2017  23:29           225.683 hafta5-1.ipynb
# 02.11.2017  23:31           145.447 hafta5-2.ipynb
# 02.11.2017  23:33           365.081 hafta5-3.ipynb
# 02.11.2017  23:35            56.617 hafta5-4.ipynb
# 02.11.2017  23:35            26.626 hafta5-5.ipynb
# 02.11.2017  23:37             2.724 hafta6-1.ipynb
# 02.11.2017  23:39             3.008 hafta6-2.ipynb
# 02.11.2017  23:41            26.656 hafta6-3.ipynb
# 03.11.2017  00:30            23.109 hafta7-1.ipynb
#               19 Dosya        3.004.412 bayt
#                3 Dizin   23.193.354.240 bayt boŸ

# %%
import matplotlib.pyplot as plt
import numpy as np
img_1=plt.imread('C:\\Users\\Karaca\\Documents\\GoruntuIsleme\\test_1.jpg')

# %%
img_1.ndim,img_1.shape
# Out:
# (3, (768, 1024, 3))

# %%
plt.imshow(img_1)
plt.show()

# %%
plt.imshow(img_1[:,:,1]+50)
plt.show()
