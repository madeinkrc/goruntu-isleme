# %%
cd C:\\Users\\Karaca\\Documents\\GoruntuIsleme
# Out:
# C:\Users\Karaca\Documents\GoruntuIsleme

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.misc import imsave

var=plt.imread("varx.jpg")
yok=plt.imread("yokx.jpg")
plt.subplot(1,2,1)
plt.imshow(var)
plt.subplot(1,2,2)
plt.imshow(yok)
plt.show()

# %%
fark=var-yok
plt.imshow(fark)
plt.show()

# %%
plt.imsave('deneme.png',fark)
