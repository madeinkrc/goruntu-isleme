# %%
import matplotlib.pyplot as plt
import numpy as np
img_1=plt.imread('C:\\Users\\Karaca\\Documents\\GoruntuIsleme\\test_1.jpg')

# %%
img_1.ndim,img_1.shape
# Out:
# (3, (768, 1024, 3))

# %%
plt.imshow(img_1)
plt.show()

# %%
def convertRGBPixelToGrayLevel(RGB_Pixel):
    return RGB_Pixel[0]/3 + RGB_Pixel[1]/3 + RGB_Pixel[2]/3

# %%
convertRGBPixelToGrayLevel([2,5,7])
# Out:
# 4.666666666666667

# %%
img_2=np.zeros((img_1.shape[0],img_1.shape[1]))
img_2.shape
# Out:
# (768, 1024)

# %%
#img_1 in her bir pixel için yukarıdaki fonksiyon çağırılır ve uygulanır.

for i in range (img_1.shape[0]):
    for j in range (img_2.shape[1]):
        img_2[i,j]=convertRGBPixelToGrayLevel(img_1[i,j,:])

# %%
img_2.ndim
# Out:
# 2

# %%
plt.subplot(1,2,1)
plt.imshow(img_1)
plt.subplot(1,2,2)
plt.imshow(img_2,cmap='gray')
plt.show()
