# %%
a=10
print(a)
# Out:
# 10

# %%
import math
def findDistance(x,y):
    return math.sqrt(
    (x[0]-y[0])**2
    +
    (x[1]-y[1])**2
    )

# %%
d=findDistance([3,0],[0,4])
d
# Out:
# 5.0

# %%
from scipy import ndimage
from scipy import misc
f=misc.face()
import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

# %%
f.ndim
# Out:
# 3

# %%
f.shape
# Out:
# (768, 1024, 3)

# %%
type(f)
# Out:
# numpy.ndarray

# %%
#Resimdeki RGB den 2:Blue değeri 0 yapıldı, mavi değeri kayboldu.
f[:,:,2]=0
plt.imshow(f)
plt.show()

# %%
type(f.shape)
# Out:
# tuple

# %%
im_size=f.shape
im_size[0] , im_size[1]
# Out:
# (768, 1024)

# %%
center=[im_size[0]/2,im_size[1]/2]
center
# Out:
# [384.0, 512.0]

# %%
center[0]
# Out:
# 384.0
