# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
#ilgili resim c klasöründe!
img=mpimg.imread(r'c:\stinkbug.png')

# %%
img.ndim
# Out:
# 3

# %%
img.shape
# Out:
# (375, 500, 3)

# %%
plt.imshow(img)
plt.show()

# %%
img[:,100,:].max()
# Out:
# 0.627451

# %%
#1:375:2 x bileşeni için 375 -> 1 den oraya kadar 2 şer 2 şer git.
img_1=img[1:375:2,:,:]

# %%
#1:375:2 y bileşeni için 500 -> 1 den oraya kadar 2 şer 2 şer git.
img_1=img[:,1:500:2,:]

# %%
#plt.subplot(1,2,1),plt.imshow(img)
#plt.subplot(1,2,2),plt.imshow(img_1)
plt.imshow(img_1)
plt.show()

# %%
img_2=img[1:375:2,:,1]
img_2=img[:,1:500:1,1]

# %%
plt.imshow(img_2)
plt.show()
